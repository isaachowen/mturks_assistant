# %% [markdown]
# # This notebook is meant to purge previously scraped data from your new scrape, in the case that you are working from a huge reference file. If this is the first scrape in a batch this notebook may not be necessary.

# %%
## If using Google colab
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# %%
import pandas as pd
import io
import numpy as np
import os

# %% [markdown]
# ## Initialize the directory system

# %%
curr_project_name = "project_erudition_emails_2"
notebook_path = "/mnt/c/Users/isaac/Desktop/mturks_assistant_github/mturks_assistant/notebooks"

dir_list = ["1_mIn_unis","2_mOut_dirs","3_notebookProcessed_dirs","4_manualCleaned_mIn_dirs","5_mOut_clubs","6_notebookProcessed_clubs","7_manualCleaned_mIn_clubs","8_mOut_leads","9_notebookProcessed_leads","10_manualCleaned_leads"]

if not os.path.isdir(notebook_path+"/../"+curr_project_name):
  os.mkdir(notebook_path+"/../"+curr_project_name)
for d in dir_list:
  if not os.path.isdir(notebook_path+"/../"+curr_project_name+"/"+d):
    os.mkdir(notebook_path+"/../"+curr_project_name+"/"+d)

# %% [markdown]
# ## Automatically import data (list of all universities/categories)

# %%
fullList_filename = 'allDATuniversities_northamerica.xlsx'
fullList_path = notebook_path+"/../"+ fullList_filename
print(fullList_path)
df_fullList=pd.read_excel(fullList_path)
# Out:
# /mnt/c/Users/isaac/Desktop/mturks_assistant_github/mturks_assistant/notebooks/../allDATuniversities_northamerica.xlsx

# %% [markdown]
# ## Filter out the unneeded data (categories/universities that you've already scraped in previous project batches)

# %%
# load in the other dataframes
previous_input_filenames =['previous_batch_of_universities.xlsx']
previous_project_names = ["project_erudition_emails_1"]

df_dict = {}
for project_no in range(len(previous_project_names)):
  df_dict["df_previous_{0}".format(project_no)] = pd.read_excel(notebook_path+"../"+previous_project_names[project_no]+"/"+previous_input_filenames[project_no])
  #previous_input_filepath = notebook_path +  + previous_input_filename
  #df_previous = pd.read_excel(previous_input_filepath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b1f1700bfa26> in <module>
#       6 df_dict = {}
#       7 for project_no in range(len(previous_project_names)):
# ----> 8   df_dict["df_previous_{0}".format(project_no)] = pd.read_excel(absolute_path+"../"+previous_project_names[project_no]+"/"+previous_input_filenames[project_no])
#       9   #previous_input_filepath = absolute_path +  + previous_input_filename
#      10   #df_previous = pd.read_excel(previous_input_filepath)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
# Vertically concatenate the other dataframes into one
  # Check that the schemas are all the same for the dataframes
flag = False
for key in pd_dict:
  if not (pd_dict["df_previous_0"].columns.intersection(pd_dict[key]) == pd_dict["df_previous_0"].columns)
    flag = True
    print(key)

  # Vertically concatenate the dataframes into one df
if not flag:
  df_curr = pd.DataFrame().reindex_like(pd_dict["df_previous_0"])
  for key in pd_dict:
    df_curr = pd.concat([df_curr,pd_dict[key]])

df_old = df_curr
df_old.head()

# %%
df_new = df_fullList.loc[~df_fullList['university_name'].isin(df_old['university_name'])]
df_new.head()
# Out:
#                       university_name  ...  country
# 1  The University of British Columbia  ...   Canada
# 2             Simon Fraser University  ...   Canada
# 4              University of Waterloo  ...   Canada
# 5                     York University  ...   Canada
# 7                  Queen's University  ...   Canada
#
# [5 rows x 6 columns]

# %%
output_filename = 'blastx_universities.xlsx'
df_new.to_excel(notebook_path+"/../"+curr_project_name+"/1_mIn/"+output_filename,index=False)
